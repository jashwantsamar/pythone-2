# %%
1)Explain with an example each when to use a for loop and a while loop?
ans-###Both for loops and while loops are used to repeat a set of instructions or statements. However, there are situations where one type of loop is more appropriate than the other. Here are some examples:
When to use a for loop:
A for loop is useful when you know the number of times you want to repeat a set of instructions. It can be more concise and easier to read than a while loop in situations where you need to iterate through a specific range of values. For example, if you want to print the numbers from 1 to 10, you can use a for loop like this
 
    for i in range(1, 11):
    print(i)
    This will print the numbers 1 to 10 to the console.
    When to use a while loop:
A while loop is useful when you don't know the number of times you want to repeat a set of instructions. It is often used in situations where you need to keep repeating a set of instructions until a certain condition is met. For example, if you want to keep asking a user for input until they enter a valid response, you can use a while loop like this:
alid_response = False

while not valid_response:
    user_input = input("Please enter a valid response: ")
    if user_input.lower() in ["yes", "no"]:
        valid_response = True
    else:
        print("Invalid response. Please enter 'yes' or 'no'.")
        
2) rite a python program to print the sum and product of the first 10 natural numbers using for
and while loop.
ans-# Sum and product of first 10 natural numbers using for loop
sum = 0
product = 1

for i in range(1, 11):
    sum += i
    product *= i

print("Sum of first 10 natural numbers is:", sum)
print("Product of first 10 natural numbers is:", product)
# Sum and product of first 10 natural numbers using while loop
sum = 0
product = 1
i = 1

while i <= 10:
    sum += i
    product *= i
    i += 1

print("Sum of first 10 natural numbers is:", sum)
print("Product of first 10 natural numbers is:", product)
Sum of first 10 natural numbers is: 55
Product of first 10 natural numbers is: 3628800

3) Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
that list.
The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
ans-units = int(input("Enter the number of units consumed: "))
total_bill = 0

if units <= 100:
    total_bill = units * 4.5
elif units <= 200:
    total_bill = 100 * 4.5 + (units - 100) * 6
elif units <= 300:
    total_bill = 100 * 4.5 + 100 * 6 + (units - 200) * 10
else:
    total_bill = 100 * 4.5 + 100 * 6 + 100 * 10 + (units - 300) * 20

print("Your total electricity bill is: Rs.", total_bill)
[2, 3, 4, 5, 6, 8, 10, 12, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 36, 40, 45, 48, 50, 54, 60, 64, 72, 75, 80, 81, 90, 96, 100]


5) Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
that list.
ans-cubes_list = []

for i in range(1, 101):
    cube = i**3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_list.append(i)

print(cubes_list)
cubes_list = []
i = 1

while i <= 100:
    cube = i**3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_list.append(i)
    i += 1

print(cubes_list)
[2, 3, 4, 5, 6, 8, 10, 12, 15, 16, 18, 20, 21, 24, 25, 27, 30, 32, 36, 40, 45, 48, 50, 54, 60, 64, 72, 75, 80, 81, 90, 96, 100]

6)Write a program to filter count vowels in the below-given string.
string = "I want to become a data scientist"
ans-string = "I want to become a data scientist"
vowels = "aeiouAEIOU"
count = 0

for char in string:
    if char in vowels:
        count += 1

print("The number of vowels in the string is:", count)
The number of vowels in the string is: 12
# Out:
#   Cell In[4], line 10
#     A while loop is useful when you don't know the number of times you want to repeat a set of instructions. It is often used in situations where you need to keep repeating a set of instructions until a certain condition is met. For example, if you want to keep asking a user for input until they enter a valid response, you can use a while loop like this:
#                                        ^
# SyntaxError: unterminated string literal (detected at line 10)
